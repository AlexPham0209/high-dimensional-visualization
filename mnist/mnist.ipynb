# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import umap
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading MNIST Digit Dataset

# %%
(x, y), _ = tf.keras.datasets.mnist.load_data()
print(f"Shape of x: {x.shape}")
print(f"Shape of y: {y.shape}")

plt.imshow(x[0])
plt.show()
# Out:
# Shape of x: (60000, 28, 28)
# Shape of y: (60000,)

# %% [markdown]
# ## Standardizing Images

# %%
x = x.reshape(x.shape[0], -1) / 255.
# x = StandardScaler().fit_transform(x)

plt.imshow(x[0].reshape(28, 28))
plt.show()

# %% [markdown]
# ## Get first 1000 samples

# %%
x = x[:3000]
y = y[:3000]

# %% [markdown]
# ## Principal Component Analysis

# %%
x_tranformed = PCA(n_components=2).fit_transform(x)
df = pd.DataFrame({"x": x_tranformed[:, 0], "y": x_tranformed[:, 1], "label": y})
# sns.scatterplot(x="x", y="y", hue="label", palette="tab10", data=df)
g = sns.FacetGrid(data=df, hue="label", height=8)
g.map(plt.scatter, 'x', 'y').add_legend()
plt.show()

# %% [markdown]
# ## TSNE

# %%
x_tranformed = TSNE(n_components=2).fit_transform(x)
df = pd.DataFrame({"x": x_tranformed[:, 0], "y": x_tranformed[:, 1], "label": y})
# sns.scatterplot(x="x", y="y", hue="label", palette="tab10", data=df)
g = sns.FacetGrid(data=df, hue="label", height=8)
g.map(plt.scatter, 'x', 'y').add_legend()
plt.show()

# %% [markdown]
# ## UMAP

# %%
x_tranformed = umap.UMAP(n_components=2).fit_transform(x)
df = pd.DataFrame({"x": x_tranformed[:, 0], "y": x_tranformed[:, 1], "label": y})
# sns.scatterplot(x="x", y="y", hue="label", palette="tab10", data=df)
g = sns.FacetGrid(data=df, hue="label", height=8)
g.map(plt.scatter, 'x', 'y').add_legend()
plt.show()

# %%
model = tf.keras.models.load_model("models/encoder2.keras")
x_tranformed = model.predict(x)
df = pd.DataFrame({"x": x_tranformed[:, 0], "y": x_tranformed[:, 1], "label": y})
g = sns.FacetGrid(data=df, hue="label", height=8)
g.map(plt.scatter, 'x', 'y').add_legend()
plt.show()
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
